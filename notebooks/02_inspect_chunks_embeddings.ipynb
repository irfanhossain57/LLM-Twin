# %% [markdown]
# # Inspect Chunks & Embeddings
# Sanity-check chunking and retrieval quality before fine-tuning.

# %%
from inference_pipeline.retriever import retrieve

results = retrieve("a sample query about one of your own topics", top_k=5)
for r in results:
    print(r['score'], '-', r['text'][:120])
