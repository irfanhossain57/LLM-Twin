# %% [markdown]
# # Evaluation Results
# Review LLM-judge scores and the production-readiness gate outcome.

# %%
from evaluation.metrics import aggregate
import json

report = aggregate()
print(json.dumps(report, indent=2))
