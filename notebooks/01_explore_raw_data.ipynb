# %% [markdown]
# # Explore Raw Data
# Inspect what's been crawled into the data warehouse so far.

# %%
from data_collection.data_warehouse import load_all_documents

docs = load_all_documents()
print(f"Total raw documents: {len(docs)}")
for source in set(d['source'] for d in docs):
    count = len([d for d in docs if d['source'] == source])
    print(f"  {source}: {count}")
